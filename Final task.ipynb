# %% [markdown]
# # Task completion using dataset_11142 csv file

# %% [markdown]
# # Resham Rajpal - EN17EL301114

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('dataset.csv')

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
df.columns=['satisfaction_level', 'last_evaluation', 'number_project', 'average_monthly_hours', 'time_spend_company', 'Work_accident', 'left', 'promotion_last_5years', 'Department', 'salary']
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_monthly_hours  time_spend_company  Work_accident  left  \
# 0                        157                   3              0     1
# 1                        262                   6              0     1
# ...

# %%
df
df.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# Department               0
# salary                   0
# dtype: int64

# %%
import seaborn as sns
sns.set_style("whitegrid")
sns.lmplot(x='number_project',y='time_spend_company',hue='left',data=df)
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df['total_count'] = (df['satisfaction_level'] + df['last_evaluation'])/2
df.head(3)
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
#
#    salary  total_count
# 0     low        0.455
# 1  medium        0.830
# 2  medium        0.495

# %%
sal = df ['salary']
project  = df ['number_project']
plt.scatter(sal,project,color='red')

# %%
sns.countplot(df['salary'],hue=df['Department'],palette='YlOrRd_r')

# %%
sns.countplot(df['average_montly_hours'],hue = df['number_project'],palette='Oranges_r' )

# %%
df.groupby(['time_spend_company']).mean()
# Out:
#                     satisfaction_level  last_evaluation  number_project  \
# time_spend_company
# 2                             0.697078         0.717596        3.687423
# 3                             0.626314         0.668721        3.327798
# 4                             0.467517         0.767927        4.627689
# 5                             0.610305         0.813666        4.519348
# 6                             0.603440         0.754875        4.213092
# 7                             0.635957         0.682766        3.851064
# 8                             0.665062         0.711975        3.777778
# 10                            0.655327         0.731495        3.682243
#
#                     average_montly_hours  Work_accident      left  \
# time_spend_company
# 2                             200.133169       0.172010  0.016338
# 3                             186.632935       0.138910  0.246159
# 4                             223.455221       0.124364  0.348064
# ...

# %%
df.groupby(['average_montly_hours']).mean()
# Out:
#                       satisfaction_level  last_evaluation  number_project  \
# average_montly_hours
# 96                              0.530000         0.681667        3.833333
# 97                              0.524286         0.627857        4.071429
# 98                              0.579565         0.654783        3.913043
# 99                              0.430000         0.634545        3.727273
# 100                             0.483158         0.606842        3.526316
# ...                                  ...              ...             ...
# 306                             0.107778         0.856111        6.277778
# 307                             0.215000         0.908571        6.214286
# 308                             0.102500         0.886000        6.500000
# 309                             0.111250         0.845000        6.000000
# 310                             0.151111         0.838333        6.222222
#
# ...

# %%
df.groupby(['time_spend_company','average_montly_hours']).mean()
# Out:
#                                          satisfaction_level  last_evaluation  \
# time_spend_company average_montly_hours
# 2                  96                              0.245000         0.825000
#                    97                              0.356667         0.583333
#                    98                              0.580000         0.700000
#                    99                              0.436667         0.593333
#                    100                             0.580000         0.510000
# ...                                                     ...              ...
# 10                 272                             0.660000         0.650000
#                    273                             0.880000         0.785000
#                    274                             0.480000         0.650000
#                    275                             0.140000         0.580000
#                    284                             0.470000         0.790000
#
# ...

# %%
df['total_count'].value_counts()
# Out:
# 0.690    184
# 0.740    180
# 0.720    180
# 0.445    180
# 0.790    179
#         ...
# 0.690      1
# 0.400      1
# 0.365      1
# 0.445      1
# 0.485      1
# Name: total_count, Length: 235, dtype: int64

# %%
dept_satis = df.groupby(['number_project','total_count']).mean().reset_index()
print(dept_satis)
sns.factorplot(x='number_project', y='total_count', data=dept_satis, kind='bar',size=5)
# Out:
#      number_project  total_count  satisfaction_level  last_evaluation  \
# 0                 2        0.260            0.150000         0.370000
# 1                 2        0.285            0.160000         0.410000
# 2                 2        0.300            0.210000         0.390000
# 3                 2        0.300            0.140000         0.460000
# 4                 2        0.310            0.170000         0.450000
# ..              ...          ...                 ...              ...
# 994               7        0.535            0.103636         0.966364
# 995               7        0.540            0.470000         0.610000
# 996               7        0.555            0.510000         0.600000
# 997               7        0.565            0.660000         0.470000
# 998               7        0.575            0.310000         0.840000
#
#      average_montly_hours  time_spend_company  Work_accident  left  \
# ...

# %%
import matplotlib.pyplot as plt
boxplot = sns.boxplot( y = 'number_project' ,x ='Department'  ,data = df )
plt.setp(boxplot.get_xticklabels(), rotation=45)
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
import matplotlib.pyplot as plt
print(df)
bplot = sns.boxplot( y = 'total_count', x = 'number_project',data = df  )
_= plt.setp(bplot.get_xticklabels(), rotation=45)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
sns.scatterplot(x=df['satisfaction_level'], y=df['last_evaluation'])
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
print(df)
sns.boxplot( y = 'total_count' ,x ='Department' , data = df)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df['number_project'].value_counts()
# Out:
# 4    4365
# 3    4055
# 5    2761
# 2    2388
# 6    1174
# 7     256
# Name: number_project, dtype: int64

# %% [markdown]
# sns.countplot(data = df , x = 'number_project')

# %%
print(df)
sns.countplot(data = df , x = 'number_project')
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
sns.countplot(df['time_spend_company'],hue=df['number_project'],palette = 'winter')

# %%
df['number_project'].value_counts()
# Out:
# 4    4365
# 3    4055
# 5    2761
# 2    2388
# 6    1174
# 7     256
# Name: number_project, dtype: int64

# %% [markdown]
# # Thankyou
